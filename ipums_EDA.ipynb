# %% [markdown]
# <a href="https://colab.research.google.com/github/gksidhu/development_econ/blob/master/ipums_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %run ipums_lib.py
rows = row_generator(datapath = "usa_00201.dat", ddipath = "usa_00201.xml")

# %%
data = []
for index, row in enumerate(rows):
    data.append(row)
print(len(data))
# Out:
# 33145

# %%
import pandas as pd

# %%
df = pd.DataFrame(data=data)

# %%
df
# Out:
#        YEAR  SAMPLE    SERIAL  ... INCWAGE_SP INCWAGE_MOM2 INCWAGE_POP2
# 0      2018  201801  00000007  ...
# 1      2018  201801  00000011  ...
# 2      2018  201801  00000012  ...
# 3      2018  201801  00000013  ...
# 4      2018  201801  00000014  ...
# ...     ...     ...       ...  ...        ...          ...          ...
# 33140  2018  201801  00024912  ...
# 33141  2018  201801  00024915  ...     000000
# 33142  2018  201801  00024915  ...     000000
# 33143  2018  201801  00024916  ...     000000
# 33144  2018  201801  00024916  ...
#
# [33145 rows x 94 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33145 entries, 0 to 33144
# Data columns (total 94 columns):
# YEAR            33145 non-null object
# SAMPLE          33145 non-null object
# SERIAL          33145 non-null object
# CBSERIAL        33145 non-null object
# HHWT            33145 non-null object
# CLUSTER         33145 non-null object
# STATEFIP        33145 non-null object
# COUNTYFIP       33145 non-null object
# MET2013         33145 non-null object
# CITY            33145 non-null object
# CITYPOP         33145 non-null object
# PUMA            33145 non-null object
# STRATA          33145 non-null object
# GQ              33145 non-null object
# MORTGAGE        33145 non-null object
# MORTAMT1        33145 non-null object
# HHINCOME        33145 non-null object
# VALUEH          33145 non-null object
# PERNUM          33145 non-null object
# CBPERNUM        33145 non-null object
# PERWT           33145 non-null object
# NCHILD          33145 non-null object
# ...

# %%
len(df.columns)
# Out:
# 94

# %%
for column in list(df.columns):
  if df[column].isna().any() == False:
    pass
  if df[column].isna().any() == True:
    print(column)

# %%
df = df.apply(pd.to_numeric, errors='ignore')
df.to_csv('ipums.csv', index=False)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

df.boxplot(figsize=(15,15));

# %%
import seaborn as sns
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(), center=0, cmap = 'cividis');

# %%
feat30 = df.iloc[:, 0:30]
feat30.hist(figsize=(30,20));

# %%
feat60 = df.iloc[:, 31:61]
feat60.hist(figsize=(30,20));

# %%
feat90 = df.iloc[:, 62:94]
feat90.hist(figsize=(20,10));
